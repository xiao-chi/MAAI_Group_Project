# %%
from google.colab import drive 
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
#data = pd.read_csv('/content/gdrive/My Drive/Data/train.csv')
data_validation = pd.read_csv('/content/gdrive/My Drive/Data/validation.csv')

# %%
RANGE =[]
CLICKS=[]
SPENT=[]
CTR=[]
CPM=[]
CPC=[]
IMPRESSIONS=[]

#lower bound 
for i in range(20,150,10):
  #upper bound 
  for j in range(200, 151,-20):
    
    print ('for [', i ,' , ', j, ' ]' )
    
    Agents=pd.DataFrame()
    Total_Clicks =0
    Total_spent  =0
    Total_CTR =0
    Total_CPM =0
    Total_CPC =0 
    Total_Impressions =0
    Range= ''+str(i)+', '+str(j)
    
    
    
    print ('Loading bid values for 51 agents randomly' )
    for k in range (1,52):
      bids=[]
      for l in range(len(data_validation)):
        bid_price = np.random.randint(i, j)
        bids.append(bid_price)
      Agents['Agent_'+str(k)]=bids
      
    print ('Loading DONE!' )
    
    
    for m in range(1,52):
      
      budget = 6250000
      impressions = 0
      clicks = 0
      bidprices_for_agent= Agents['Agent_'+str(m)].values
      data = Agents.drop(columns=['Agent_'+str(m)])
      
      print('Agent ',m)
      
      for x, y in data.iterrows():
        bidprice = bidprices_for_agent[x]
        highest_among_bids =y.max()
        
        if (bidprice>=highest_among_bids and bidprice >= data_validation['payprice'][x]):
          
            payprice = max(highest_among_bids,data_validation['payprice'][x])
            
            budget= budget-payprice
            if (budget>=0): 
                impressions+=1
                if (data_validation['click'][x]==1):
                    clicks +=1
            else:
                budget= budget+payprice
                break
      
      Total_Clicks +=clicks
      Total_Impressions += impressions
      
      CtR = clicks/impressions
      Total_CTR +=CtR
      
      
      Spent = 6250000 - budget
      Total_spent  +=Spent
      
      cPM = 1000*Spent/impressions
      Total_CPM += cPM
      
      
      if (clicks >0):
        ecPC = Spent/clicks
      else:
        ecPC =0
        
      Total_CPC += ecPC

    avg_clicks = Total_Clicks/51
    avg_spent =Total_spent/51
    avg_ctr = Total_CTR/51
    avg_cpm = Total_CPM/51
    avg_cpc = Total_CPC/51
    avg_impressions= Total_Impressions/51
    
    RANGE.append(Range)
    CLICKS.append(avg_clicks)
    SPENT.append(avg_spent)
    CTR.append(avg_ctr)
    CPM.append(avg_cpm)
    CPC.append(avg_cpc)
    IMPRESSIONS.append(avg_impressions)
    
    print ('DOne with this ',Range, 'moving on to next ---> ')
    print ('impressions =',avg_impressions,' Clicks =',avg_clicks,' Spent amount = ',avg_spent, ' eCPC is ',avg_cpc) 
    print ( ' CTR =',avg_ctr, ' CPM is ',avg_cpm)
# Out:
# for [ 100  ,  200  ]
# Loading bid values for 51 agents randomly
# Loading DONE!
# Agent  1
# Agent  2
# Agent  3
# Agent  4
# Agent  5
# Agent  6
# Agent  7
# Agent  8
# Agent  9
# Agent  10
# Agent  11
# Agent  12
# Agent  13
# Agent  14
# Agent  15
# Agent  16
# Agent  17
# Agent  18
# Agent  19
# Agent  20
# Agent  21
# Agent  22
# Agent  23
# Agent  24
# Agent  25
# Agent  26
# Agent  27
# Agent  28
# Agent  29
# Agent  30
# Agent  31
# Agent  32
# Agent  33
# Agent  34
# Agent  35
# Agent  36
# Agent  37
# Agent  38
# Agent  39
# Agent  40
# Agent  41
# Agent  42
# Agent  43
# Agent  44
# Agent  45
# Agent  46
# Agent  47
# Agent  48
# Agent  49
# Agent  50
# Agent  51
# DOne with this  100, 200 moving on to next --->
# impressions = 7117.058823529412  Clicks = 4.235294117647059  Spent amount =  1395398.137254902  eCPC is  397949.35634920635
#  CTR = 0.0005945669743355926  CPM is  196063.89818462273
# for [ 100  ,  180  ]
# Loading bid values for 51 agents randomly
# ...
