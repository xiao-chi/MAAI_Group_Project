# %%
# from google.colab import drive
# drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from sklearn.utils import resample

# %%
# df = pd.read_csv('/content/gdrive/My Drive/we_data/train.csv')
df = pd.read_csv('/Desktop/jupyternb/we_data/train.csv')
df.head()
# Out:
#    click  weekday  hour                                     bidid  \
# 0      0        5    22  b7bea80521fdecd95d2d761a38c91c3f09618066
# 1      0        1    20  4f51205475678f5a124bc76b2c54163bf8eaa7eb
# 2      0        3    13  b604e3fd054a658ab7ced4285ebf2ef54d2bd890
# 3      0        6    23  0348beeae93e561584c3b50fc9e7746a33048ad7
# 4      0        5     6  268149c1789bce2bc9798ffd97ec431219bafeb3
#
#                                      userid       useragent             IP  \
# 0  2e880fb7d690cf7377b2e42e701728e3f3c0e4c1      windows_ie   125.37.175.*
# 1  3a1fe01360ff8100e7d006b83b77a3e4c01d928c  windows_chrome    171.36.92.*
# 2  801d18a056b6fe6b06a794aef17fb0d6daff2414      windows_ie    59.46.106.*
# 3  0d6eaf2259699990e38a1fc5116f112070b9ecdc      windows_ie  114.250.226.*
# 4  a239d9bb642460d974ba67f85e63b8d3e214da0e      windows_ie   183.63.192.*
#
#    region  city  adexchange           ...            slotheight  \
# ...

# %%
cat_vars=['region','weekday','useragent','adexchange','slotwidth','slotheight','slotvisibility','advertiser']

for i in cat_vars:
    one_hot = pd.get_dummies(df[i],prefix=i)
    df = df.drop(i,axis = 1)
    df = df.join(one_hot)

df.head()
# Out:
#          click  hour                                     bidid  \
# 0            0    22  b7bea80521fdecd95d2d761a38c91c3f09618066
# 1            0    20  4f51205475678f5a124bc76b2c54163bf8eaa7eb
# 2            0    13  b604e3fd054a658ab7ced4285ebf2ef54d2bd890
# 3            0    23  0348beeae93e561584c3b50fc9e7746a33048ad7
# 4            0     6  268149c1789bce2bc9798ffd97ec431219bafeb3
# 5            0    17  1be2cf4a47a2a6aee4b0fa64d1b786d3897be4f0
# 6            0    12  6b4f23dd215a5f11136c2f29214236cfee1f0122
# 7            0    16  f7c1d8ea177211249456c79e194617ce107bc077
# 8            0    14  9e97694096fe8692851048a893231a7f7ff87922
# 9            0     0  d1b7c7fdb88ce3aa78a540bb29848dd77329a574
# 10           0    16  14be67cc32f1a108f7a2737205146708d41a9edf
# 11           0    18  699d636b4456c7ec1dceca3943b0fec735a88336
# 12           0    21  83be02e32b55209c39ae3f0b76f0149f73585910
# 13           0    21  619e54af34510d6c5c81694bb11350db56b7f230
# ...

# %%
# Downsample majority class and combine minority class with downsampled majority class
df_majority = pd.concat([resample(df[df.click==0], replace=False, n_samples=10000, random_state=123), df[df.click==1]])
 
# Upsample minority class and Combine majority class with upsampled minority class
df1 = pd.concat([df_majority, resample(df[df.click==1], replace=True, n_samples=10000-1793, random_state=123)])
 
# Display new class counts
df1.head()
# Out:
#          click  hour                                     bidid  \
# 1148805      0    13  5d00ac4203cfb7176a2dd74609e6df1373d1396d
# 1867729      0     1  eb546d7bd897a45c82acf057c60d7fb1eb55330f
# 354090       0    23  89f91d62f59a8ab688a1f6f0f2df9919fb94c53f
# 642202       0    22  0aa4c41698d3274ed47e2a879eddaab6a5ac5ead
# 1678178      0    12  c9880874d1b486a8e203cab822e4895b3c800a4a
#
#                                            userid             IP  city  \
# 1148805  61a591cdb6e77cb56ec6487b10c05d56f6359362   61.133.143.*   107
# 1867729  fb3e30c5118829a0b7702957263d61aa1a430216     58.61.14.*   219
# 354090   fb9ca42ee00d19355ef5335e0eda46e12c5779e5  110.208.113.*   216
# 642202   eca38f2004d3205c46ab5e99e1bff1abd303c5e2  124.115.221.*   334
# 1678178  f67980a9c7eedced82160bfe6bbacd52834916d1      1.85.38.*   334
#
#                                    domain                               url  \
# 1148805  b57fdfdc11993baed9c4b4ef265f4717  626bba387bc56e4fc51299dccd5ea9af
# ...

# %%
# df1['usertag'] = df1['usertag'].fillna(0)

# %%
# df1.to_csv(path_or_buf='/content/gdrive/My Drive/we_data/train_ver_1.csv',sep='\t',index=False)

# %%
# s = pd.read_csv('/content/gdrive/My Drive/we_data/train_ver_1.csv')
